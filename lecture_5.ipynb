# %%
import covid19_recovered as cr
import pandas as pd
import linRegNumpy as lrn

# %%
all_data = pd.read_csv('time_series_covid19_recovered4.9.csv')

# %%
# area_data = 'area_price.csv'
data_italy = cr.get_italy_data(all_data)

# %%
area_data = 'area_price.csv'

# %%
lrn.main_linear_regression(area_data)
# Out:
# area_price.csv
# 449.0 202.07176942858692
# 59.75196191493018 236.99618783941258
